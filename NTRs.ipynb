# %%
import pandas as pd
import numpy as np
df1=pd.read_csv(r"C:\Users\chand\Downloads\NTRS (1).csv")
df1.dropna(axis=0,inplace=True)
print(df1)
df2012=df1.loc[0:248]
df2012
# Out:
#       Unnamed: 0        Date  Algerian dinar   (DZD)                       \
# 0              0  2012-01-03                                      76.3243
# 1              1  2012-01-04                                      76.3243
# 2              2  2012-01-05                                      76.3243
# 3              3  2012-01-06                                      76.3243
# 4              4  2012-01-09                                      76.5183
# ...          ...         ...                                          ...
# 2643        2643  2022-08-22                                     141.0594
# 2644        2644  2022-08-23                                     141.2180
# 2645        2645  2022-08-24                                     140.9474
# 2646        2646  2022-08-25                                     140.6518
# 2647        2647  2022-08-26                                     140.4196
#
#       Australian dollar   (AUD)                       \
# ...

# %%
df2012.describe()
# Out:
#        Unnamed: 0  Algerian dinar   (DZD)                       \
# count  249.000000                                   249.000000
# mean   124.000000                                    77.553862
# std     72.024301                                     2.516153
# min      0.000000                                    73.745700
# 25%     62.000000                                    74.738100
# 50%    124.000000                                    78.083300
# 75%    186.000000                                    79.497100
# max    248.000000                                    82.103000
#
#        Australian dollar   (AUD)                       \
# count                                      249.000000
# mean                                         0.965876
# std                                          0.021541
# min                                          0.924556
# 25%                                          0.954016
# 50%                                          0.963298
# ...

# %%
df2012.max()
# Out:
# Unnamed: 0                                                 248
# Date                                                2012-12-28
# Algerian dinar   (DZD)                                  82.103
# Australian dollar   (AUD)                             1.033592
# Bahrain dinar   (BHD)                                    0.376
# Bolivar Fuerte   (VEF)                                  4.2893
# Botswana pula   (BWP)                                 8.045052
# Brazilian real   (BRL)                                  2.1121
# Brunei dollar   (BND)                                   1.2994
# Canadian dollar   (CAD)                                 1.0418
# Chilean peso   (CLP)                                    519.69
# Chinese yuan   (CNY)                                    6.3495
# Colombian peso   (COP)                                  1942.7
# Czech koruna   (CZK)                                    21.133
# Danish krone   (DKK)                                    6.1537
# ...

# %%
df2012.min()
# Out:
# Unnamed: 0                                                   0
# Date                                                2012-01-03
# Algerian dinar   (DZD)                                 73.7457
# Australian dollar   (AUD)                             0.924556
# Bahrain dinar   (BHD)                                    0.376
# Bolivar Fuerte   (VEF)                                  4.2893
# Botswana pula   (BWP)                                 7.107321
# Brazilian real   (BRL)                                  1.7024
# Brunei dollar   (BND)                                   1.2183
# Canadian dollar   (CAD)                                  0.971
# Chilean peso   (CLP)                                    469.65
# Chinese yuan   (CNY)                                     6.267
# Colombian peso   (COP)                                 1707.47
# Czech koruna   (CZK)                                    18.448
# Danish krone   (DKK)                                    5.5266
# ...

# %%
df2012.plot(x='Date',y='Indian rupee   (INR)                     ',kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
x=int(input("Enter a number to convert from USD TO INR :"))
y=input("Enter date :")
dfINR=df1[['Indian rupee   (INR)                     ','Date']]
out=float(df1['Indian rupee   (INR)                     '].loc[(df1['Date']==y)])

print(x," USD to INR in the date ",y," is : Rs.",x*out)
# Out:
# Enter a number to convert from USD TO INR :10
# Enter date :2012-01-06
# 10  USD to INR in the date  2012-01-06  is : Rs. 527.8

# %%
dfINR
# Out:
#       Indian rupee   (INR)                             Date
# 0                                       53.2300  2012-01-03
# 1                                       53.1400  2012-01-04
# 2                                       52.7800  2012-01-05
# 3                                       52.7800  2012-01-06
# 4                                       52.7300  2012-01-09
# ...                                         ...         ...
# 2643                                    79.8703  2022-08-22
# 2644                                    79.8903  2022-08-23
# 2645                                    79.7927  2022-08-24
# 2646                                    79.8705  2022-08-25
# 2647                                    79.9097  2022-08-26
#
# [2648 rows x 2 columns]
