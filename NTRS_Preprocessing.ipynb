# %%
import pandas as pd
# !pip install jupyter-dash

import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
ntrs = pd.read_csv(r"C:\Users\Admin\Downloads\NTRS_Dataset.csv")
ntrs.head()
# Out:
#        Date  Algerian dinar   (DZD)                       \
# 0  3-Jan-12                                          NaN
# 1  4-Jan-12                                          NaN
# 2  5-Jan-12                                          NaN
# 3  6-Jan-12                                      76.3243
# 4  9-Jan-12                                      76.5183
#
#    Australian dollar   (AUD)                       \
# 0                                        0.971440
# 1                                        0.965904
# 2                                        0.968711
# 3                                        0.978378
# 4                                        0.983284
#
#    Bahrain dinar   (BHD)                       \
# 0                                       0.376
# 1                                       0.376
# 2                                       0.376
# 3                                       0.376
# 4                                       0.376
#
# ...

# %%
ntrs.isnull()
# Out:
#        Date  Algerian dinar   (DZD)                       \
# 0     False                                         True
# 1     False                                         True
# 2     False                                         True
# 3     False                                        False
# 4     False                                        False
# ...     ...                                          ...
# 2643  False                                        False
# 2644  False                                        False
# 2645  False                                        False
# 2646  False                                        False
# 2647  False                                        False
#
#       Australian dollar   (AUD)                       \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# ...

# %%
ntrs['Date'] = pd.to_datetime(ntrs['Date']).dt.date

# %%
ntrs
# Out:
#             Date  Algerian dinar   (DZD)                       \
# 0     2012-01-03                                          NaN
# 1     2012-01-04                                          NaN
# 2     2012-01-05                                          NaN
# 3     2012-01-06                                      76.3243
# 4     2012-01-09                                      76.5183
# ...          ...                                          ...
# 2643  2022-08-22                                     141.0594
# 2644  2022-08-23                                     141.2180
# 2645  2022-08-24                                     140.9474
# 2646  2022-08-25                                     140.6518
# 2647  2022-08-26                                     140.4196
#
#       Australian dollar   (AUD)                       \
# 0                                           0.971440
# 1                                           0.965904
# 2                                           0.968711
# ...

# %%
ntrs.interpolate(inplace = True)
ntrs
# Out:
#             Date  Algerian dinar   (DZD)                       \
# 0     2012-01-03                                          NaN
# 1     2012-01-04                                          NaN
# 2     2012-01-05                                          NaN
# 3     2012-01-06                                      76.3243
# 4     2012-01-09                                      76.5183
# ...          ...                                          ...
# 2643  2022-08-22                                     141.0594
# 2644  2022-08-23                                     141.2180
# 2645  2022-08-24                                     140.9474
# 2646  2022-08-25                                     140.6518
# 2647  2022-08-26                                     140.4196
#
#       Australian dollar   (AUD)                       \
# 0                                           0.971440
# 1                                           0.965904
# 2                                           0.968711
# ...

# %%
ntrs.fillna(method = 'bfill', inplace = True)
ntrs
# Out:
#             Date  Algerian dinar   (DZD)                       \
# 0     2012-01-03                                      76.3243
# 1     2012-01-04                                      76.3243
# 2     2012-01-05                                      76.3243
# 3     2012-01-06                                      76.3243
# 4     2012-01-09                                      76.5183
# ...          ...                                          ...
# 2643  2022-08-22                                     141.0594
# 2644  2022-08-23                                     141.2180
# 2645  2022-08-24                                     140.9474
# 2646  2022-08-25                                     140.6518
# 2647  2022-08-26                                     140.4196
#
#       Australian dollar   (AUD)                       \
# 0                                           0.971440
# 1                                           0.965904
# 2                                           0.968711
# ...

# %%
ntrs.isnull()
# Out:
#        Date  Algerian dinar   (DZD)                       \
# 0     False                                        False
# 1     False                                        False
# 2     False                                        False
# 3     False                                        False
# 4     False                                        False
# ...     ...                                          ...
# 2643  False                                        False
# 2644  False                                        False
# 2645  False                                        False
# 2646  False                                        False
# 2647  False                                        False
#
#       Australian dollar   (AUD)                       \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# ...

# %%
ntrs.to_csv('NTRS.csv')
